# %%
import pandas as pd
url = './archive/cleaned_imdb_2024.csv'
df = pd.read_csv(url, sep=',')
print(df.isnull().sum())
# Out:
# Home_Page             0
# Movie_Name            0
# Genres                0
# Overview              0
# Cast                  0
# Original_Language     0
# Storyline             0
# Production_Company    0
# Release_Date          0
# Tagline               0
# Vote_Average          0
# Vote_Count            0
# Budget_USD            0
# Revenue_$             0
# Run_Time_Minutes      0
# Release_Country       0
# dtype: int64

# %%
drop = df.dropna() #remove qualquer linha com pelo menos 1 valor nulo
print(drop)
# Out:
#                                   Home_Page  \
# 0     https://www.imdb.com/title/tt5040012/
# 1    https://www.imdb.com/title/tt20221436/
# 2     https://www.imdb.com/title/tt8999762/
# 3    https://www.imdb.com/title/tt27657135/
# 4    https://www.imdb.com/title/tt17526714/
# ..                                      ...
# 496  https://www.imdb.com/title/tt28288478/
# 497  https://www.imdb.com/title/tt20519854/
# 498  https://www.imdb.com/title/tt28349451/
# 499  https://www.imdb.com/title/tt31609000/
# 500  https://www.imdb.com/title/tt14203572/
#
#                               Movie_Name  \
# 0                              Nosferatu
# 1                           Emilia Pérez
# 2                          The Brutalist
# 3                         Saturday Night
# 4                          The Substance
# ..                                   ...
# 496                             The Cage
# 497  The Man Who Could Not Remain Silent
# 498                    The Shadow Strays
# ...

# %%
print(df.head())
# Out:
#                                 Home_Page      Movie_Name  \
# 0   https://www.imdb.com/title/tt5040012/       Nosferatu
# 1  https://www.imdb.com/title/tt20221436/    Emilia Pérez
# 2   https://www.imdb.com/title/tt8999762/   The Brutalist
# 3  https://www.imdb.com/title/tt27657135/  Saturday Night
# 4  https://www.imdb.com/title/tt17526714/   The Substance
#
#                                               Genres  \
# 0                   ['Fantasy', 'Horror', 'Mystery']
# 1  ['Comedy', 'Crime', 'Drama', 'Musical', 'Thril...
# 2                                          ['Drama']
# 3        ['Biography', 'Comedy', 'Drama', 'History']
# 4                      ['Drama', 'Horror', 'Sci-Fi']
#
#                                             Overview  \
# 0  A gothic tale of obsession between a haunted y...
# 1  Emilia Pérez follows three remarkable women in...
# 2  When a visionary architect and his wife flee p...
# 3  At 11:30pm on October 11th, 1975, a ferocious ...
# ...
